# %%
# %pip install pandas langchain-experimental matplotlib langchain-community langchain-ollama pypdf
# Out:
# Requirement already satisfied: pandas in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: langchain-experimental in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (0.4.1)
# Requirement already satisfied: matplotlib in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (3.10.8)
# Requirement already satisfied: langchain-community in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-ollama in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (1.0.1)
# Requirement already satisfied: pypdf in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (6.4.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langchain-experimental) (1.2.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langchain-community) (2.0.45)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langchain-community) (0.5.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-experimental) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-experimental) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-experimental) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-experimental) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-experimental) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: anyio in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.12.0)
# Requirement already satisfied: certifi in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.2)
# Requirement already satisfied: greenlet>=1 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: ollama<1.0.0,>=0.6.0 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from langchain-ollama) (0.6.1)
# Requirement already satisfied: six>=1.5 in c:\users\пользователь\desktop\myragproject\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import CharacterTextSplitter, RecursiveCharacterTextSplitter
from langchain_experimental.text_splitter import SemanticChunker
from langchain_ollama import OllamaEmbeddings

# Путь к файлу (мы в папке notebooks, поэтому выходим на уровень вверх .., потом в data/docs)
PDF_PATH = "../data/docs/sample.pdf"

# Загружаем
print("Загружаю PDF...")
loader = PyPDFLoader(PDF_PATH)
docs = loader.load()

# Склеиваем весь текст в одну большую строку для чистоты эксперимента
full_text = " ".join([d.page_content for d in docs])

print(f"Готово! Длина текста: {len(full_text)} символов.")
# Out:
# Загружаю PDF...
# Готово! Длина текста: 13549 символов.

# %%
print("--- 1. FIXED SIZE CHUNKING ---")

# Настройки: 1000 символов, 0 перекрытия
splitter_fixed = CharacterTextSplitter(
    separator="", # Режем где попало, даже посреди слова
    chunk_size=1000,
    chunk_overlap=0
)
chunks_fixed = splitter_fixed.split_text(full_text)

print(f"Количество чанков: {len(chunks_fixed)}")

# Посмотрим, как он разрезал (ищем обрывки слов)
print(f"\nПример стыка (конец 1-го и начало 2-го чанка):")
print(f"ЧАНК 1 (конец): ...{chunks_fixed[0][-50:]}")
print(f"ЧАНК 2 (начало): {chunks_fixed[1][:50]}...")
# Out:
# --- 1. FIXED SIZE CHUNKING ---
# Количество чанков: 14
#
# Пример стыка (конец 1-го и начало 2-го чанка):
# ЧАНК 1 (конец): ...-vector .svg 1 / 1 ,
# S.G. CHEKANO V
# Communic ate d
# ЧАНК 2 (начало): by S.V. Sudopla to v
# Abstract: The w ork has b egu...

# %%
print("--- 2. RECURSIVE CHUNKING ---")

# Настройки: 1000 символов, но с перекрытием 200 (чтобы не терять контекст на границах)
splitter_recursive = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200,
    separators=["\n\n", "\n", " ", ""] # Приоритеты разделения
)
chunks_recursive = splitter_recursive.split_text(full_text)

print(f"Количество чанков: {len(chunks_recursive)}")
print(f"Первый чанк:\n{chunks_recursive[0][:200]}...")
# Out:
# --- 2. RECURSIVE CHUNKING ---
# Количество чанков: 17
# Первый чанк:
# Math-Net.Ru
# Общероссийский математический портал
# A. A. Stepanova, E. L. Efremov, S. G. Chekanov, Pseudoﬁnite S-acts,
# Сиб. электрон. матем. изв., 2024, том 21, выпуск 1, 271–276
# https://www.mathnet.ru/...

# %%
print("--- 3. SEMANTIC CHUNKING ---")
print("Запускаю анализ смысла (может занять 1-2 минуты, так как работает локально)...")

# Подключаем локальные эмбеддинги
embeddings = OllamaEmbeddings(model="all-minilm")

# Создаем "умный" сплиттер
splitter_semantic = SemanticChunker(embeddings, breakpoint_threshold_type="percentile")

chunks_semantic = splitter_semantic.split_text(full_text)

print(f"Готово! Количество чанков: {len(chunks_semantic)}")
# Out:
# --- 3. SEMANTIC CHUNKING ---
# Запускаю анализ смысла (может занять 1-2 минуты, так как работает локально)...
# Готово! Количество чанков: 25

# %%
# Собираем статистику
data = {
    "Метод": ["Fixed (Тупой)", "Recursive (Стандарт)", "Semantic (Умный)"],
    "Кол-во чанков": [len(chunks_fixed), len(chunks_recursive), len(chunks_semantic)],
    "Средняя длина (символов)": [
        int(sum(len(c) for c in chunks_fixed)/len(chunks_fixed)),
        int(sum(len(c) for c in chunks_recursive)/len(chunks_recursive)),
        int(sum(len(c) for c in chunks_semantic)/len(chunks_semantic))
    ]
}

df = pd.DataFrame(data)
display(df) # Или просто print(df)
# Out:
#                   Метод  Кол-во чанков  Средняя длина (символов)
# 0         Fixed (Тупой)             14                       967
# 1  Recursive (Стандарт)             17                       944
# 2      Semantic (Умный)             25                       540

# %% [markdown]
# ВЫВОД:
# Для моего документа (научная статья по математике) лучшей стратегией показал себя Semantic Chunking.
#
# 1. Fixed Chunking разрывает слова и формулы, что недопустимо в точных науках.
# 2. Recursive Chunking хорош, но он объединяет несколько разных определений в один блок из-за большого размера (1000).
# 3. Semantic Chunking создал больше всего фрагментов (25), но они меньше по размеру (540 символов). Это значит, что он выделил каждое определение и теорему в отдельный логический блок. Это даст наиболее точные ответы при поиске.
